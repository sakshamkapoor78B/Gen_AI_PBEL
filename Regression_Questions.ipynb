# %% [markdown]
# A CSV file (students.csv) contains information about students, including
# Study Hours, Attendance (%), and Exam Marks.
# Perform the following tasks:
# 1. Load the dataset using Pandas.
# 2. Check for missing values and remove them.
# 3. Use NumPy to calculate:
# o Mean
# o Median
# o Standard Deviation of Marks
# 4. Create:
# o Histogram of Marks
# o Scatter plot of Study Hours vs Marks
# 5. Build a Simple Linear Regression model to predict Marks based on Study
# Hours.
# 6. Display regression line and predicted values.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
# load Dataset
df = pd.read_csv("/content/drive/MyDrive/Gen_AI_PBEL/CSV/StudentPerformanceFactors-selected-columns.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#       Sleep_Hours  Previous_Scores  Gender  Exam_Score
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#    Sleep_Hours  Previous_Scores  Gender  Exam_Score
# 0            7               73    Male          67
# 1            8               59  Female          61
# 2            7               91    Male          74
# 3            8               98    Male          71
# 4            6               65  Female          70

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#       Sleep_Hours  Previous_Scores  Gender  Exam_Score
# 6602            7               76  Female          68
# 6603            8               81  Female          69
# 6604            6               65  Female          68
# 6605            6               91  Female          68
# 6606            9               94    Male          64

# %%
df.shape
# Out:
# (6607, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hours_Studied         6607 non-null   int64
#  1   Attendance            6607 non-null   int64
#  2   Parental_Involvement  6607 non-null   object
#  3   Access_to_Resources   6607 non-null   object
#  4   Sleep_Hours           6607 non-null   int64
#  5   Previous_Scores       6607 non-null   int64
#  6   Gender                6607 non-null   object
#  7   Exam_Score            6607 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 413.1+ KB

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores   Exam_Score
# count    6607.000000  6607.000000   6607.00000      6607.000000  6607.000000
# mean       19.975329    79.977448      7.02906        75.070531    67.235659
# std         5.990594    11.547475      1.46812        14.399784     3.890456
# min         1.000000    60.000000      4.00000        50.000000    55.000000
# 25%        16.000000    70.000000      6.00000        63.000000    65.000000
# 50%        20.000000    80.000000      7.00000        75.000000    67.000000
# 75%        24.000000    90.000000      8.00000        88.000000    69.000000
# max        44.000000   100.000000     10.00000       100.000000   101.000000

# %%
df.isnull().sum()
# Out:
# Hours_Studied           0
# Attendance              0
# Parental_Involvement    0
# Access_to_Resources     0
# Sleep_Hours             0
# Previous_Scores         0
# Gender                  0
# Exam_Score              0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Hours_Studied           0
# Attendance              0
# Parental_Involvement    0
# Access_to_Resources     0
# Sleep_Hours             0
# Previous_Scores         0
# Gender                  0
# Exam_Score              0
# dtype: int64

# %%
df = df.rename(columns={
    "Hours_Studied": "Study Hours",
    "Attendance": "Attendance",
    "Exam_Score": "Marks"
})
df
# Out:
#       Study Hours  Attendance Parental_Involvement Access_to_Resources  \
# 0              23          84                  Low                High
# 1              19          64                  Low              Medium
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 4              19          92               Medium              Medium
# ...           ...         ...                  ...                 ...
# 6602           25          69                 High              Medium
# 6603           23          76                 High              Medium
# 6604           20          90               Medium                 Low
# 6605           10          86                 High                High
# 6606           15          67               Medium                 Low
#
#       Sleep_Hours  Previous_Scores  Gender  Marks
# 0               7               73    Male     67
# ...

# %%
marks = df["Marks"]
study_hours = df["Study Hours"]

# %%
Mean = np.mean(marks)
print (Mean)
Median = np.median(marks)
print (Median)
Standard_Deviation = np.std(marks)
print (Standard_Deviation)
# Out:
# 67.23565914938702
# 67.0
# 3.890161350884698

# %%
plt.hist(marks)
plt.title("Histogram of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(study_hours ,marks)
plt.title("Scatter Plot of Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
# Simple Linear Regression
X = df[["Study Hours"]]
y = df["Marks"]

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred)
# Out:
# [68.11066807 66.95350555 68.3999587  ... 67.24279618 64.3498899
#  65.79634304]

# %%
plt.figure(figsize=(6,4))
plt.scatter(X, y, label="Actual Data")
plt.plot(X,y_pred, color="red", linewidth=3, label = "Linear Regression")
plt.title("Linear Regression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Problem Statement: Car Mileage Prediction
# A dataset contains:
#  Engine Size
#  Car Weight
#  Mileage (km/l)
# Perform the following:
# 1. Read dataset.
# 2. Calculate descriptive statistics.
# 3. Plot:
# o Scatter plot of Weight vs Mileage
# o Histogram of Mileage
# 4. Build a Linear Regression model to predict mileage using engine size.
# 5. Display regression line.

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/drive/MyDrive/Gen_AI_PBEL/CSV/Car_Mileage_Data.csv")
df
# Out:
#      Engine_Size_Liters  Car_Weight_kg  Horsepower        MPG
# 0              2.498160    1370.265858  150.660535  31.013611
# 1              4.802857    2083.801895  146.684276  16.268459
# 2              3.927976    2745.891672  324.688737  13.468015
# 3              3.394634    2464.449773  147.377474  16.722438
# 4              1.624075    2613.122296  153.426426  28.981412
# ..                  ...            ...         ...        ...
# 995            1.366328    2313.910313  313.629855  29.266311
# 996            4.669254    2913.229242  122.463766  11.404165
# 997            1.547275    1137.916033  163.642722  37.255994
# 998            4.800949    1114.109442  158.312294  21.016797
# 999            2.784023    1564.374149  315.281789  23.070399
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#    Engine_Size_Liters  Car_Weight_kg  Horsepower        MPG
# 0            2.498160    1370.265858  150.660535  31.013611
# 1            4.802857    2083.801895  146.684276  16.268459
# 2            3.927976    2745.891672  324.688737  13.468015
# 3            3.394634    2464.449773  147.377474  16.722438
# 4            1.624075    2613.122296  153.426426  28.981412

# %%
df.tail()
# Out:
#      Engine_Size_Liters  Car_Weight_kg  Horsepower        MPG
# 995            1.366328    2313.910313  313.629855  29.266311
# 996            4.669254    2913.229242  122.463766  11.404165
# 997            1.547275    1137.916033  163.642722  37.255994
# 998            4.800949    1114.109442  158.312294  21.016797
# 999            2.784023    1564.374149  315.281789  23.070399

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Engine_Size_Liters  1000 non-null   float64
#  1   Car_Weight_kg       1000 non-null   float64
#  2   Horsepower          1000 non-null   float64
#  3   MPG                 1000 non-null   float64
# dtypes: float64(4)
# memory usage: 31.4 KB

# %%
df.describe()
# Out:
#        Engine_Size_Liters  Car_Weight_kg   Horsepower          MPG
# count         1000.000000    1000.000000  1000.000000  1000.000000
# mean             2.961026    2014.034610   215.649546    22.296792
# std              1.168549     584.379787    78.482033     6.711277
# min              1.018528    1006.436527    80.003141     5.488195
# 25%              1.943893    1482.148542   150.564764    17.338034
# 50%              2.987230    2037.467813   215.165758    22.489929
# 75%              3.977278    2520.930115   284.957952    27.108267
# max              4.998871    2998.827452   349.411631    37.584397

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.isnull().sum()
# Out:
# Engine_Size_Liters    0
# Car_Weight_kg         0
# Horsepower            0
# MPG                   0
# dtype: int64

# %%
weight = df["Car_Weight_kg"]
mileage = df["MPG"]
engine_size = df["Engine_Size_Liters"]

# %%
plt.figure(figsize=(6,4))
plt.scatter(weight,mileage)
plt.title("Scatter plot of Weight vs Mileage")
plt.xlabel("Weight")
plt.ylabel("Mileage")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(mileage)
plt.title("Histogram of Mileage")
plt.xlabel("Mileage")
plt.show()

# %%
# Linear Regression"
X = df[["Engine_Size_Liters"]]
y = df["MPG"]

model = LinearRegression()
model.fit(X,y)

y_pred = model.predict(X)
print(y_pred)
# Out:
# [24.45129168 13.72362619 17.79593446 20.27847918 28.51989693 28.52034602
#  30.34332854 15.29762434 20.23274161 18.24132128 31.04151669 13.36622838
#  15.92570135 27.471278   28.03941439 28.01000522 25.76015299 21.65444589
#  23.38248198 26.0024412  20.03281524 28.82756832 25.98539554 24.60356127
#  22.93330434 16.80574967 27.70709107 21.85035266 20.39473332 30.55992462
#  20.11302578 28.24982241 30.21359318 13.75767565 13.44587619 16.37339557
#  25.75323562 29.60623859 18.68518485 23.22966874 29.15257093 22.20518075
#  30.78450244 14.49433055 26.60660523 19.08941257 25.62109236 21.74173841
#  21.24569183 27.98300898 13.37228366 16.99274073 13.9324427  14.76417362
#  20.29260163 14.26059339 29.77715184 27.77581153 30.58269771 25.36751834
#  24.18807469 26.37258474 15.99468641 24.78246021 26.19411475 21.3204313
#  28.80093667 16.4888389  30.03673236 13.05013563 17.0465128  27.72492975
#  31.32195991 16.24187095 18.26394747 17.85154457 17.06465537 30.04615332
# ...

# %%
plt.figure(figsize=(6,4))
plt.scatter(X,y,label = "Actual Data")
plt.plot(X,y_pred,color = "red", label ="Regression Line")
plt.title("Regression Line")
plt.xlabel("Engine Size")
plt.ylabel("Mileage")
plt.grid()
plt.show()
